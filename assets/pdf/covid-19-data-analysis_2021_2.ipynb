# %% [markdown]
# # Pandas 실습 - 전 세계 코로나19 데이터 분석
#
# * 분석 대상 데이터 : [Microsoft Bing COVID-19 Dataset](https://docs.microsoft.com/en-us/azure/open-datasets/dataset-bing-covid-19?tabs=azure-storage)
# * Microsoft에서 서비스하는 검색엔진인 Bing에서 제공하는 "[Bing 코로나19 추적기](https://bing.com/covid)"에서 사용되는 실제 Dataset
# * 전 세계 모든 지역의 확진, 사망 및 완치 사례가 포함되며, 데이터는 매일 업데이트 됨
# * 21년 11월 30일 CSV 파일 기준 1,942,762행, 총 파일 크기 343.3MB
# * 목표 : 나만의 코로나 19 Dashboard 만들기

# %% [markdown]
# ### 필요 패키지 import
# pandas + numpy + matplotlib %matplotlib inline 의 경우 matplotlib 로 출력하는 plot을 jupyter notebook 내에서 바로 출력하라는 jupyter notebook 특수 명령어임.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### CSV로 부터 DataFrame 생성하기

# %%
df = pd.read_csv("https://pandemicdatalake.blob.core.windows.net/public/curated/covid-19/bing_covid-19_data/latest/bing_covid-19_data.csv",  low_memory=False)
df.head(10)
# Out:
#        id     updated  confirmed  confirmed_change  deaths  deaths_change  \
# 0  338995  2020-01-21        262               NaN     0.0            NaN
# 1  338996  2020-01-22        313              51.0     0.0            0.0
# 2  338997  2020-01-23        578             265.0     0.0            0.0
# 3  338998  2020-01-24        841             263.0     0.0            0.0
# 4  338999  2020-01-25       1320             479.0     0.0            0.0
# 5  339000  2020-01-26       2014             694.0     0.0            0.0
# 6  339001  2020-01-27       2798             784.0     0.0            0.0
# 7  339002  2020-01-28       4593            1795.0     0.0            0.0
# 8  339003  2020-01-29       6065            1472.0     0.0            0.0
# 9  339004  2020-01-30       7818            1753.0     0.0            0.0
#
#    recovered  recovered_change  latitude  longitude iso2 iso3 country_region  \
# 0        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 1        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 2        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 3        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 4        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 5        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 6        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 7        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 8        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
# 9        NaN               NaN       NaN        NaN  NaN  NaN      Worldwide
#
#   admin_region_1 iso_subdivision admin_region_2            load_time
# 0            NaN             NaN            NaN  2021-11-30 00:06:19
# 1            NaN             NaN            NaN  2021-11-30 00:06:19
# 2            NaN             NaN            NaN  2021-11-30 00:06:19
# 3            NaN             NaN            NaN  2021-11-30 00:06:19
# 4            NaN             NaN            NaN  2021-11-30 00:06:19
# 5            NaN             NaN            NaN  2021-11-30 00:06:19
# 6            NaN             NaN            NaN  2021-11-30 00:06:19
# 7            NaN             NaN            NaN  2021-11-30 00:06:19
# 8            NaN             NaN            NaN  2021-11-30 00:06:19
# 9            NaN             NaN            NaN  2021-11-30 00:06:19

# %% [markdown]
# ### 전 세계 일별 확진자/사망자 수 시각화

# %%
# 기본 DataFrame(df)에서 country_region이 'Worldwide'인 데이터만 추출하여 df_Worldwide라는 새로운 DataFrame 생성
df_Worldwide=df[df['country_region']=='Worldwide']

# %%
# 시각화. 일자별 누적 확진자 / 누적 사망자 / 일별 확진자 / 일별 사망자 graph 그리기
df_Worldwide.plot(kind='line',x='updated',y="confirmed",grid=True, title="Worldwide confirmed cases(count)", figsize=(8, 4))
df_Worldwide.plot(kind='line',x='updated',y="deaths",grid=True, title="Worldwide deaths(count)", figsize=(8, 4))
df_Worldwide.plot(kind='line',x='updated',y="confirmed_change",grid=True, title="Worldwide daily cofirmed cases(count)" , figsize=(8, 4))
df_Worldwide.plot(kind='line',x='updated',y="deaths_change",grid=True, title="Worldwide daily deaths(count)" , figsize=(8, 4))
# Out:
# <AxesSubplot:title={'center':'Worldwide daily deaths(count)'}, xlabel='updated'>

# %% [markdown]
# ### 국가별 누적 확진자/사망자 수

# %%
df_country = df[(df['country_region']!='Worldwide') & (df.admin_region_1.isnull())]
df_country_group = df_country[["country_region", "confirmed", "deaths"]].groupby("country_region").max().sort_values("confirmed", ascending=False)
df_country_group.head(30)
# Out:
#                 confirmed    deaths
# country_region
# United States    43910849  736227.0
# India            34572523  468554.0
# Brazil           22080906  614278.0
# United Kingdom   10110408  144724.0
# Russia            9570373  272755.0
# Turkey            8702611   76041.0
# France            7620048  118894.0
# Iran              6102056  129462.0
# Germany           5761696  100883.0
# Argentina         5260652  115283.0
# Spain             5121100   87931.0
# Colombia          5065373  128437.0
# Italy             5007818  133674.0
# Indonesia         4255936  143808.0
# Mexico            3883842  293897.0
# Poland            3507828   83037.0
# Ukraine           3427827   85414.0
# South Africa      2952500   89771.0
# Philippines       2831807   48361.0
# Malaysia          2623816   30309.0
# Netherlands       2575172   19607.0
# Peru              2234075  201108.0
# Czechia           2110274   32744.0
# Thailand          2106813   20707.0
# Iraq              2078521   23765.0
# Canada            1782171   29618.0
# Romania           1776949   56275.0
# Chile             1751769   38218.0
# Japan             1726944   18357.0
# Belgium           1679861   26793.0

# %% [markdown]
# ### 국내 도시별 확진자/사망자 수 분석

# %%
# 국가명(country_region)이 "South Korea"이고 국내 전체 합계가 아닌 도시별 데이터만을 가져오기 위해 
# 도시명(admin_region_1)이 null(비어있는 값)이 아닌 경우만 가져와서 df_korea 생성
df_korea = df[(df['country_region']=='South Korea') & (~df.admin_region_1.isnull())]
df_korea.head(5)
# Out:
#              id     updated  confirmed  confirmed_change  deaths  \
# 929592  3140567  2020-04-02        122               NaN     3.0
# 929593  3430147  2020-04-04        122               0.0     3.0
# 929594  3751937  2020-04-05        122               0.0     3.0
# 929595  4016597  2020-04-06        123               1.0     3.0
# 929596  4277141  2020-04-07        125               2.0     3.0
#
#         deaths_change  recovered  recovered_change  latitude  longitude iso2  \
# 929592            NaN        NaN               NaN  35.18026   129.0711   KR
# 929593            0.0        NaN               NaN  35.18026   129.0711   KR
# 929594            0.0        NaN               NaN  35.18026   129.0711   KR
# 929595            0.0        NaN               NaN  35.18026   129.0711   KR
# 929596            0.0        NaN               NaN  35.18026   129.0711   KR
#
#        iso3 country_region admin_region_1 iso_subdivision admin_region_2  \
# 929592  KOR    South Korea          Busan             NaN            NaN
# 929593  KOR    South Korea          Busan             NaN            NaN
# 929594  KOR    South Korea          Busan             NaN            NaN
# 929595  KOR    South Korea          Busan             NaN            NaN
# 929596  KOR    South Korea          Busan             NaN            NaN
#
#                   load_time
# 929592  2021-11-30 00:06:19
# 929593  2021-11-30 00:06:19
# 929594  2021-11-30 00:06:19
# 929595  2021-11-30 00:06:19
# 929596  2021-11-30 00:06:19

# %%
# groupby 함수를 통하여 도시명(admin_region_1)으로 그룹화 하고 confirmed, deaths 수치의 최대값(=가장 최신의 확진자/사망자 수)을 가져옴
# .sort_values("정렬할 기준 열(conlumn) 이름", ascending=True/False[오름차순/내림차순])
df_province = df_korea[["admin_region_1", "confirmed", "deaths"]].groupby("admin_region_1").max().sort_values("confirmed", ascending=False)
df_province.head(20)
# Out:
#                    confirmed  deaths
# admin_region_1
# Seoul                 136376   912.0
# Gyeonggi              121624  1047.0
# Incheon                22008   123.0
# Daegu                  18093   293.0
# Busan                  15068   175.0
# South Gyeongsang       14069    46.0
# South Chungcheong      11808    72.0
# North Gyeongsang       10455    99.0
# North Chungcheong       8465    88.0
# Daejeon                 8001    56.0
# Gangwon                 7812    68.0
# North Jeolla            5852    70.0
# Gwangju                 5728    29.0
# Ulsan                   5552    57.0
# South Jeolla            3965    25.0
# Jeju                    3378     9.0
# Sejong                  1435     2.0

# %%
df_province.plot(kind="barh", figsize=(12, 4), title="Korea confirmed cases/deaths by province")
# Out:
# <AxesSubplot:title={'center':'Korea confirmed cases/deaths by province'}, ylabel='admin_region_1'>

# %% [markdown]
# ### 국내 일자/도시별 확진자 수 변화 시각화

# %%
# .pivot 함수의 경우 Excel의 피벗 테이블 기능과 유사하게 주어진 dataframe의 행/열 데이터 구조를 변환하는 역할
data_pivot_by_date = df_korea.pivot(index='updated', columns='admin_region_1', values='confirmed_change')
data_pivot_by_date.head(10)
# Out:
# admin_region_1  Busan  Daegu  Daejeon  Gangwon  Gwangju  Gyeonggi  Incheon  \
# updated
# 2020-04-02        NaN    NaN      NaN      NaN      NaN       NaN      NaN
# 2020-04-04        0.0   14.0      0.0      1.0      0.0      12.0      2.0
# 2020-04-05        0.0    NaN      NaN      NaN      NaN       NaN      NaN
# 2020-04-06        1.0    NaN      NaN      NaN      NaN       NaN      NaN
# 2020-04-07        2.0   11.0      1.0      2.0      1.0      10.0      1.0
# 2020-04-08        0.0    9.0      0.0      2.0      0.0       6.0      4.0
# 2020-04-09        1.0    4.0      0.0      0.0      0.0      10.0      1.0
# 2020-04-10        0.0    4.0      0.0      0.0      0.0       9.0      0.0
# 2020-04-11        NaN    NaN      NaN      NaN      NaN       NaN      NaN
# 2020-04-12      -86.0    4.0      0.0      0.0      0.0       8.0      1.0
#
# admin_region_1  Jeju  North Chungcheong  North Gyeongsang  North Jeolla  \
# updated
# 2020-04-02       NaN                NaN               NaN           NaN
# 2020-04-04       0.0                0.0               2.0           0.0
# 2020-04-05       NaN                NaN               NaN           NaN
# 2020-04-06       NaN                NaN               NaN           NaN
# 2020-04-07       1.0                0.0               3.0           1.0
# 2020-04-08       0.0                0.0               3.0           1.0
# 2020-04-09       0.0                0.0               4.0           0.0
# 2020-04-10       0.0                0.0               3.0           0.0
# 2020-04-11       0.0                NaN               NaN           NaN
# 2020-04-12       0.0                0.0               4.0           0.0
#
# admin_region_1  Sejong  Seoul  South Chungcheong  South Gyeongsang  \
# updated
# 2020-04-02         NaN    NaN                NaN               NaN
# 2020-04-04         0.0   11.0                0.0               1.0
# 2020-04-05         NaN    NaN                NaN               NaN
# 2020-04-06         NaN    NaN                NaN               NaN
# 2020-04-07         0.0   13.0                0.0               1.0
# 2020-04-08         0.0   11.0                1.0               2.0
# 2020-04-09         0.0   12.0                0.0               0.0
# 2020-04-10         0.0    5.0                0.0               0.0
# 2020-04-11         NaN    NaN                0.0               0.0
# 2020-04-12         0.0    8.0                1.0               0.0
#
# admin_region_1  South Jeolla  Ulsan
# updated
# 2020-04-02               NaN    NaN
# 2020-04-04               0.0    NaN
# 2020-04-05               NaN    NaN
# 2020-04-06               NaN    NaN
# 2020-04-07               0.0    NaN
# 2020-04-08               0.0    0.0
# 2020-04-09               0.0    0.0
# 2020-04-10               0.0    0.0
# 2020-04-11               0.0    NaN
# 2020-04-12               0.0    0.0

# %%
# 그래프 그리기
data_pivot_by_date.plot(figsize=(16, 10))
# Out:
# <AxesSubplot:xlabel='updated'>
